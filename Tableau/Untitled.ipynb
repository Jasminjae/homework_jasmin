# %%
import pandas as pd
import csv
from glob import glob

# %%
qtrOne_2016 = pd.read_csv('./data-milestraveled2016_1Q.csv')
qtrTwo_2016 = pd.read_csv('./data-milestraveled2016_2Q.csv')
qtrThree_2016 = pd.read_csv('./data-milestraveled2016_3Q.csv')
qtrFour_2016 = pd.read_csv('./data-milestraveled2016_4Q.csv')

# %%
df_2016 = sorted(glob('./data-milestraveled2016_*.csv'))
df_2016
# Out:
# ['./data-milestraveled2016_1Q.csv',
#  './data-milestraveled2016_2Q.csv',
#  './data-milestraveled2016_3Q.csv',
#  './data-milestraveled2016_4Q.csv']

# %%
df_2016 = pd.concat((pd.read_csv(file, encoding = "ISO-8859-1").assign(filename = file)
          for file in df_2016), ignore_index = True, sort = False)
df_2016
# Out:
#          Date  Trips over the past 24-hours (midnight to 11:59pm)  \
# 0      1/1/16                                              11009
# 1      1/2/16                                              14587
# 2      1/3/16                                              15499
# 3      1/4/16                                              19593
# 4      1/5/16                                              18053
# 5      1/6/16                                              24569
# 6      1/7/16                                              27773
# 7      1/8/16                                              28709
# 8      1/9/16                                              20846
# 9     1/10/16                                              14275
# 10    1/11/16                                              22937
# 11    1/12/16                                              25211
# 12    1/13/16                                              21133
# ...

# %%
qtrOne_2017 = pd.read_csv('./data-milestraveled2017_1Q.csv')
qtrTwo_2017 = pd.read_csv('./data-milestraveled2017_2Q.csv')
qtrThree_2017 = pd.read_csv('./data-milestraveled2017_3Q.csv')
qtrFour_2017 = pd.read_csv('./data-milestraveled2017_4Q.csv')

# %%
df_2017 = sorted(glob('./data-milestraveled2017_*.csv'))
df_2017
# Out:
# ['./data-milestraveled2017_1Q.csv',
#  './data-milestraveled2017_2Q.csv',
#  './data-milestraveled2017_3Q.csv',
#  './data-milestraveled2017_4Q.csv']

# %%
df_2017 = pd.concat((pd.read_csv(file, encoding = "ISO-8859-1").assign(filename = file)
          for file in df_2017), ignore_index = True, sort = False)
df_2017
# Out:
#          Date  Trips over the past 24-hours (midnight to 11:59pm)  \
# 0      1/1/17                                              16009
# 1      1/2/17                                               8921
# 2      1/3/17                                              14198
# 3      1/4/17                                              34039
# 4      1/5/17                                              28393
# 5      1/6/17                                              24177
# 6      1/7/17                                               4425
# 7      1/8/17                                               6417
# 8      1/9/17                                              15856
# 9     1/10/17                                              23232
# 10    1/11/17                                              32419
# 11    1/12/17                                              39783
# 12    1/13/17                                              33611
# ...

# %%
qtrOne_2018 = pd.read_csv('./data-milestraveled2018_1Q.csv')
qtrTwo_2018 = pd.read_csv('./data-milestraveled2018_2Q.csv')
qtrThree_2018 = pd.read_csv('./data-milestraveled2018_3Q.csv')
qtrFour_2018 = pd.read_csv('./data-milestraveled2018_4Q.csv')

# %%
df_2018 = sorted(glob('./data-milestraveled2018_*.csv'))
df_2018
# Out:
# ['./data-milestraveled2018_1Q.csv',
#  './data-milestraveled2018_2Q.csv',
#  './data-milestraveled2018_3Q.csv',
#  './data-milestraveled2018_4Q.csv']

# %%
df_2018 = pd.concat((pd.read_csv(file, encoding = "ISO-8859-1").assign(filename = file)
          for file in df_2018), ignore_index = True, sort = False)
df_2018
# Out:
#          Date  Trips over the past 24-hours (midnight to 11:59pm)  \
# 0      1/1/18                                               5499
# 1      1/2/18                                              18818
# 2      1/3/18                                              24299
# 3      1/4/18                                               1922
# 4      1/5/18                                               4972
# 5      1/6/18                                               4294
# 6      1/7/18                                               5640
# 7      1/8/18                                              15820
# 8      1/9/18                                              25090
# 9     1/10/18                                              28252
# 10    1/11/18                                              33961
# 11    1/12/18                                              22252
# 12    1/13/18                                              17758
# ...

# %%
df_2016.to_csv('./2016_milestraveled.csv', index=False)
df_2017.to_csv('./2017_milestraveled.csv', index=False)
df_2018.to_csv('./2018_milestraveled.csv', index=False)

# %%
qtrOne_2015 = pd.read_csv('./data-milestraveled2015_1Q.csv')
qtrTwo_2015 = pd.read_csv('./data-milestraveled2015_2Q.csv')
qtrThree_2015 = pd.read_csv('./data-milestraveled2015_3Q.csv')
qtrFour_2015 = pd.read_csv('./data-milestraveled2015_4Q.csv')

# %%
df_2015 = sorted(glob('./data-milestraveled2015_*.csv'))
df_2015
# Out:
# ['./data-milestraveled2015_1Q.csv',
#  './data-milestraveled2015_2Q.csv',
#  './data-milestraveled2015_3Q.csv',
#  './data-milestraveled2015_4Q.csv']

# %%
df_2015 = pd.concat((pd.read_csv(file, encoding = "ISO-8859-1").assign(filename = file)
          for file in df_2015), ignore_index = True, sort = False)
df_2015
# Out:
#          Date  Trips over the past 24-hours (midnight to 11:59pm)  \
# 0      1/1/15                                               5792
# 1      1/2/15                                              12371
# 2      1/3/15                                               4834
# 3      1/4/15                                               8509
# 4      1/5/15                                              15792
# 5      1/6/15                                               9483
# 6      1/7/15                                              10685
# 7      1/8/15                                               9777
# 8      1/9/15                                               8631
# 9     1/10/15                                               6826
# 10    1/11/15                                               8204
# 11    1/12/15                                               9441
# 12    1/13/15                                              14134
# ...

# %%
qtrOne_2014 = pd.read_csv('./data-milestraveled2014_1Q.csv')
qtrTwo_2014 = pd.read_csv('./data-milestraveled2014_2Q.csv')
qtrThree_2014 = pd.read_csv('./data-milestraveled2014_3Q.csv')
qtrFour_2014 = pd.read_csv('./data-milestraveled2014_4Q.csv')

# %%
df_2014 = sorted(glob('./data-milestraveled2014_*.csv'))
df_2014
# Out:
# ['./data-milestraveled2014_1Q.csv',
#  './data-milestraveled2014_2Q.csv',
#  './data-milestraveled2014_3Q.csv',
#  './data-milestraveled2014_4Q.csv']

# %%
df_2014 = pd.concat((pd.read_csv(file, encoding = "ISO-8859-1").assign(filename = file)
          for file in df_2014), ignore_index = True, sort = False)
df_2014
# Out:
#          Date  Trips over the past 24-hours (midnight to 11:59pm)  \
# 0      1/1/14                                               6559
# 1      1/2/14                                               9334
# 2      1/3/14                                               1288
# 3      1/4/14                                               2494
# 4      1/5/14                                               2937
# 5      1/6/14                                              10481
# 6      1/7/14                                               7144
# 7      1/8/14                                              10162
# 8      1/9/14                                              14571
# 9     1/10/14                                              10685
# 10    1/11/14                                               8333
# 11    1/12/14                                              13549
# 12    1/13/14                                              22377
# ...

# %%
df_2014.to_csv('./2014_milestraveled.csv', index=False)
df_2015.to_csv('./2015_milestraveled.csv', index=False)
